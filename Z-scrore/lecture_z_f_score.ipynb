# %%
import numpy as np
import pandas as pd
df = pd.read_csv('housing.csv')

house = df['latitude']
z_score = (house - np.mean(house)) / np.std(house)
print(z_score)
# Out:
# 0        1.052548
# 1        1.043185
# 2        1.038503
# 3        1.038503
# 4        1.038503
#            ...
# 20635    1.801647
# 20636    1.806329
# 20637    1.778237
# 20638    1.778237
# 20639    1.750146
# Name: latitude, Length: 20640, dtype: float64
